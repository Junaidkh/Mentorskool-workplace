# %%
#@title 
# %%html
<marquee style='width: 100%; color: #00a7f4;font-size:30px;'><b>Welcome to Mentorskool!</b></marquee>
# Out:
# <marquee style='width: 100%; color: #00a7f4;font-size:30px;'><b>Welcome to Mentorskool!</b></marquee>

# %% [markdown]
# ### **Data Ingestion - Learning to scrape the web**
# -----
# We'll be doing the following activities in this class :
#
# * Understanding an HTML page
# * Learning to web scrape : Follow along project
# * Work on a lab assignment to assess what your learnt!
# * Discussion with your guide on learnings and shortcomings

# %% [markdown]
# ### **Learning Outcomes**
# -----
# Below are the takeaways from this notebook :
#
# * Learning how to read an **HTML page** (DOM or **Document Object Model**)
# * How can Python be used to **read** an HTML page and **extract data** from the same
# * Discovering the **packages** which Python uses to implement **Web Scraping**

# %% [markdown]
# ### **01. Learning to web scrape : Follow along project**
# --------------------------------
# * Follow the article [here](https://www.dataquest.io/blog/web-scraping-beautifulsoup/) by DataQuest end-to-end and try to replicate the results as shown <br>
#   🚩 Please ensure you **type out** each piece of code instead of doing **copy-paste**. You'll discover how quickly you learn if you try **remembering** and then **typing**!
# * Use this notebook itself to write the code
# * For each piece of your code, you need to provide sufficient comments to explain what the step would do
# * Once you are done, submit your assignment in the classroom
#
# **Note :** [Here](https://medium.com/dataly-ai/mastering-web-scraping-with-python-introduction-part1-89b7ff9cb65a) is another article to develop good understanding of the process of web scraping

# %%
# start your code here
# add as many cells as you need after this to make your code look tidy

# %% [markdown]
# ### **02. Lab Assignment**
# --------------------------------
# * You are a Data Scientist hired by the BCCI to do some analysis of the IPL 2019 event concluded last year
# * Refer [this](http://www.howstat.com/cricket/Statistics/IPL/SeriesMatches.asp?s=2019) page which lists down the details of the matches held
# * Use BeautifulSoup Python package to scrape the match details
# * Your output should be a CSV file which looks like below :
# <img src="https://github.com/mentorskool/artefacts/blob/master/example.png?raw=true" width=900 height=200>
# * Your output should have all the rows as there in the source URL

# %%
import pandas as pd

# %%
# reading the html page using read_html it will save our page in list
d = pd.read_html('http://www.howstat.com/cricket/Statistics/IPL/SeriesMatches.asp?s=2019')

# FInding the length of the list
len(d)
# Out:
# 9

# %%
d[7]
# Out:
#              0  ...                                       3
# 0         Date  ...                                  Result
# 1   23/03/2019  ...    Chennai Super Kings won by 7 Wickets
# 2   24/03/2019  ...  Kolkata Knight Riders won by 6 Wickets
# 3   24/03/2019  ...           Delhi Capitals won by 37 Runs
# 4   25/03/2019  ...          Kings XI Punjab won by 14 Runs
# ..         ...  ...                                     ...
# 56  05/05/2019  ...         Mumbai Indians won by 9 Wickets
# 57  07/05/2019  ...         Mumbai Indians won by 6 Wickets
# 58  08/05/2019  ...         Delhi Capitals won by 2 Wickets
# 59  10/05/2019  ...    Chennai Super Kings won by 6 Wickets
# 60  12/05/2019  ...             Mumbai Indians won by 1 Run
#
# [61 rows x 4 columns]

# %% [markdown]
# *   Now checking on which index our desired result is stored.
# *   I have checked and found it on 8th index.

# %%
d[7] # Gotccha, yay we got our table which we are looking for.
# Out:
#              0  ...                                       3
# 0         Date  ...                                  Result
# 1   23/03/2019  ...    Chennai Super Kings won by 7 Wickets
# 2   24/03/2019  ...  Kolkata Knight Riders won by 6 Wickets
# 3   24/03/2019  ...           Delhi Capitals won by 37 Runs
# 4   25/03/2019  ...          Kings XI Punjab won by 14 Runs
# ..         ...  ...                                     ...
# 56  05/05/2019  ...         Mumbai Indians won by 9 Wickets
# 57  07/05/2019  ...         Mumbai Indians won by 6 Wickets
# 58  08/05/2019  ...         Delhi Capitals won by 2 Wickets
# 59  10/05/2019  ...    Chennai Super Kings won by 6 Wickets
# 60  12/05/2019  ...             Mumbai Indians won by 1 Run
#
# [61 rows x 4 columns]

# %%
# Now converting that list of table into dataframe
d1 = pd.DataFrame(d[7])
d1
# Out:
#              0  ...                                       3
# 0         Date  ...                                  Result
# 1   23/03/2019  ...    Chennai Super Kings won by 7 Wickets
# 2   24/03/2019  ...  Kolkata Knight Riders won by 6 Wickets
# 3   24/03/2019  ...           Delhi Capitals won by 37 Runs
# 4   25/03/2019  ...          Kings XI Punjab won by 14 Runs
# ..         ...  ...                                     ...
# 56  05/05/2019  ...         Mumbai Indians won by 9 Wickets
# 57  07/05/2019  ...         Mumbai Indians won by 6 Wickets
# 58  08/05/2019  ...         Delhi Capitals won by 2 Wickets
# 59  10/05/2019  ...    Chennai Super Kings won by 6 Wickets
# 60  12/05/2019  ...             Mumbai Indians won by 1 Run
#
# [61 rows x 4 columns]

# %%
# Making first row as Header
new_header = d1.iloc[0]
d1 = d1[1:]
d1.columns = new_header

# %%
d1
# Out:
# 0         Date  ...                                        Result
# 1   23/03/2019  ...          Chennai Super Kings won by 7 Wickets
# 2   24/03/2019  ...        Kolkata Knight Riders won by 6 Wickets
# 3   24/03/2019  ...                 Delhi Capitals won by 37 Runs
# 4   25/03/2019  ...                Kings XI Punjab won by 14 Runs
# 5   26/03/2019  ...          Chennai Super Kings won by 6 Wickets
# 6   27/03/2019  ...          Kolkata Knight Riders won by 28 Runs
# 7   28/03/2019  ...                  Mumbai Indians won by 6 Runs
# 8   29/03/2019  ...          Sunrisers Hyderabad won by 5 Wickets
# 9   30/03/2019  ...    Match tied (Delhi Capitals won eliminator)
# 10  30/03/2019  ...              Kings XI Punjab won by 8 Wickets
# 11  31/03/2019  ...           Sunrisers Hyderabad won by 118 Runs
# 12  31/03/2019  ...             Chennai Super Kings won by 8 Runs
# 13  01/04/2019  ...                Kings XI Punjab won by 14 Runs
# 14  02/04/2019  ...             Rajasthan Royals won by 7 Wickets
# 15  03/04/2019  ...                 Mumbai Indians won by 37 Runs
# 16  04/04/2019  ...          Sunrisers Hyderabad won by 5 Wickets
# 17  05/04/2019  ...        Kolkata Knight Riders won by 5 Wickets
# 18  06/04/2019  ...            Chennai Super Kings won by 22 Runs
# 19  06/04/2019  ...                 Mumbai Indians won by 40 Runs
# 20  07/04/2019  ...               Delhi Capitals won by 4 Wickets
# 21  07/04/2019  ...        Kolkata Knight Riders won by 8 Wickets
# 22  08/04/2019  ...              Kings XI Punjab won by 6 Wickets
# 23  09/04/2019  ...          Chennai Super Kings won by 7 Wickets
# 24  10/04/2019  ...               Mumbai Indians won by 3 Wickets
# 25  11/04/2019  ...          Chennai Super Kings won by 4 Wickets
# 26  12/04/2019  ...               Delhi Capitals won by 7 Wickets
# 27  13/04/2019  ...             Rajasthan Royals won by 4 Wickets
# 28  13/04/2019  ...  Royal Challengers Bangalore won by 8 Wickets
# 29  14/04/2019  ...          Chennai Super Kings won by 5 Wickets
# 30  14/04/2019  ...                 Delhi Capitals won by 39 Runs
# 31  15/04/2019  ...               Mumbai Indians won by 5 Wickets
# 32  16/04/2019  ...                Kings XI Punjab won by 12 Runs
# 33  17/04/2019  ...          Sunrisers Hyderabad won by 6 Wickets
# 34  18/04/2019  ...                 Mumbai Indians won by 40 Runs
# 35  19/04/2019  ...    Royal Challengers Bangalore won by 10 Runs
# 36  20/04/2019  ...             Rajasthan Royals won by 5 Wickets
# 37  20/04/2019  ...               Delhi Capitals won by 5 Wickets
# 38  21/04/2019  ...          Sunrisers Hyderabad won by 9 Wickets
# 39  21/04/2019  ...      Royal Challengers Bangalore won by 1 Run
# 40  22/04/2019  ...               Delhi Capitals won by 6 Wickets
# 41  23/04/2019  ...          Chennai Super Kings won by 6 Wickets
# 42  24/04/2019  ...    Royal Challengers Bangalore won by 17 Runs
# 43  25/04/2019  ...             Rajasthan Royals won by 3 Wickets
# 44  26/04/2019  ...                 Mumbai Indians won by 46 Runs
# 45  27/04/2019  ...             Rajasthan Royals won by 7 Wickets
# 46  28/04/2019  ...                 Delhi Capitals won by 16 Runs
# 47  28/04/2019  ...          Kolkata Knight Riders won by 34 Runs
# 48  29/04/2019  ...            Sunrisers Hyderabad won by 45 Runs
# 49  30/04/2019  ...                                     No result
# 50  01/05/2019  ...            Chennai Super Kings won by 80 Runs
# 51  02/05/2019  ...    Match tied (Mumbai Indians won eliminator)
# 52  03/05/2019  ...        Kolkata Knight Riders won by 7 Wickets
# 53  04/05/2019  ...               Delhi Capitals won by 5 Wickets
# 54  04/05/2019  ...  Royal Challengers Bangalore won by 4 Wickets
# 55  05/05/2019  ...              Kings XI Punjab won by 6 Wickets
# 56  05/05/2019  ...               Mumbai Indians won by 9 Wickets
# 57  07/05/2019  ...               Mumbai Indians won by 6 Wickets
# 58  08/05/2019  ...               Delhi Capitals won by 2 Wickets
# 59  10/05/2019  ...          Chennai Super Kings won by 6 Wickets
# 60  12/05/2019  ...                   Mumbai Indians won by 1 Run
#
# [60 rows x 4 columns]

# %%
# Changing the column name
d1 = d1.rename(columns={'Ground / Location':'Ground'})

# %%
# Checking our Data frame
d1
# Out:
# 0         Date  ...                                        Result
# 1   23/03/2019  ...          Chennai Super Kings won by 7 Wickets
# 2   24/03/2019  ...        Kolkata Knight Riders won by 6 Wickets
# 3   24/03/2019  ...                 Delhi Capitals won by 37 Runs
# 4   25/03/2019  ...                Kings XI Punjab won by 14 Runs
# 5   26/03/2019  ...          Chennai Super Kings won by 6 Wickets
# 6   27/03/2019  ...          Kolkata Knight Riders won by 28 Runs
# 7   28/03/2019  ...                  Mumbai Indians won by 6 Runs
# 8   29/03/2019  ...          Sunrisers Hyderabad won by 5 Wickets
# 9   30/03/2019  ...    Match tied (Delhi Capitals won eliminator)
# 10  30/03/2019  ...              Kings XI Punjab won by 8 Wickets
# 11  31/03/2019  ...           Sunrisers Hyderabad won by 118 Runs
# 12  31/03/2019  ...             Chennai Super Kings won by 8 Runs
# 13  01/04/2019  ...                Kings XI Punjab won by 14 Runs
# 14  02/04/2019  ...             Rajasthan Royals won by 7 Wickets
# 15  03/04/2019  ...                 Mumbai Indians won by 37 Runs
# 16  04/04/2019  ...          Sunrisers Hyderabad won by 5 Wickets
# 17  05/04/2019  ...        Kolkata Knight Riders won by 5 Wickets
# 18  06/04/2019  ...            Chennai Super Kings won by 22 Runs
# 19  06/04/2019  ...                 Mumbai Indians won by 40 Runs
# 20  07/04/2019  ...               Delhi Capitals won by 4 Wickets
# 21  07/04/2019  ...        Kolkata Knight Riders won by 8 Wickets
# 22  08/04/2019  ...              Kings XI Punjab won by 6 Wickets
# 23  09/04/2019  ...          Chennai Super Kings won by 7 Wickets
# 24  10/04/2019  ...               Mumbai Indians won by 3 Wickets
# 25  11/04/2019  ...          Chennai Super Kings won by 4 Wickets
# 26  12/04/2019  ...               Delhi Capitals won by 7 Wickets
# 27  13/04/2019  ...             Rajasthan Royals won by 4 Wickets
# 28  13/04/2019  ...  Royal Challengers Bangalore won by 8 Wickets
# 29  14/04/2019  ...          Chennai Super Kings won by 5 Wickets
# 30  14/04/2019  ...                 Delhi Capitals won by 39 Runs
# 31  15/04/2019  ...               Mumbai Indians won by 5 Wickets
# 32  16/04/2019  ...                Kings XI Punjab won by 12 Runs
# 33  17/04/2019  ...          Sunrisers Hyderabad won by 6 Wickets
# 34  18/04/2019  ...                 Mumbai Indians won by 40 Runs
# 35  19/04/2019  ...    Royal Challengers Bangalore won by 10 Runs
# 36  20/04/2019  ...             Rajasthan Royals won by 5 Wickets
# 37  20/04/2019  ...               Delhi Capitals won by 5 Wickets
# 38  21/04/2019  ...          Sunrisers Hyderabad won by 9 Wickets
# 39  21/04/2019  ...      Royal Challengers Bangalore won by 1 Run
# 40  22/04/2019  ...               Delhi Capitals won by 6 Wickets
# 41  23/04/2019  ...          Chennai Super Kings won by 6 Wickets
# 42  24/04/2019  ...    Royal Challengers Bangalore won by 17 Runs
# 43  25/04/2019  ...             Rajasthan Royals won by 3 Wickets
# 44  26/04/2019  ...                 Mumbai Indians won by 46 Runs
# 45  27/04/2019  ...             Rajasthan Royals won by 7 Wickets
# 46  28/04/2019  ...                 Delhi Capitals won by 16 Runs
# 47  28/04/2019  ...          Kolkata Knight Riders won by 34 Runs
# 48  29/04/2019  ...            Sunrisers Hyderabad won by 45 Runs
# 49  30/04/2019  ...                                     No result
# 50  01/05/2019  ...            Chennai Super Kings won by 80 Runs
# 51  02/05/2019  ...    Match tied (Mumbai Indians won eliminator)
# 52  03/05/2019  ...        Kolkata Knight Riders won by 7 Wickets
# 53  04/05/2019  ...               Delhi Capitals won by 5 Wickets
# 54  04/05/2019  ...  Royal Challengers Bangalore won by 4 Wickets
# 55  05/05/2019  ...              Kings XI Punjab won by 6 Wickets
# 56  05/05/2019  ...               Mumbai Indians won by 9 Wickets
# 57  07/05/2019  ...               Mumbai Indians won by 6 Wickets
# 58  08/05/2019  ...               Delhi Capitals won by 2 Wickets
# 59  10/05/2019  ...          Chennai Super Kings won by 6 Wickets
# 60  12/05/2019  ...                   Mumbai Indians won by 1 Run
#
# [60 rows x 4 columns]

# %%
# Now saving our data frame and exporting it into csv format
from google.colab import drive
drive.mount('drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at drive

# %%
d1.to_csv('junaidkh190.csv')
# !cp junaidkh190.csv "drive/My Drive/"
